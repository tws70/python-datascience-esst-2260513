# %%
import numpy as np
import pandas as pd

from pandas import Series, DataFrame

# %%
data = {'Fahrzeug': ['Auto', 'Motorrad', 'Motorrad', 'Auto', 'Auto'],  'PS': [380, 70, 124, 165,156]}
DF_obj = pd.DataFrame(data)
DF_obj
# Out:
#    Fahrzeug   PS
# 0      Auto  380
# 1  Motorrad   70
# 2  Motorrad  124
# 3      Auto  165
# 4      Auto  156

# %%
gr=DF_obj.groupby(['Fahrzeug'])
print(gr)
# average of the group
gr.mean()
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000278FB162DD0>
#                   PS
# Fahrzeug
# Auto      233.666667
# Motorrad   97.000000

# %%
# sum of the group
gr.sum()
# Out:
#            PS
# Fahrzeug
# Auto      701
# Motorrad  194

# %%
# min value in the group
gr.min()
# Out:
#            PS
# Fahrzeug
# Auto      156
# Motorrad   70

# %%
# max value in the group
gr.max()
# Out:
#            PS
# Fahrzeug
# Auto      380
# Motorrad  124
